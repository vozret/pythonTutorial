# %%
pwd
# Out:
# '/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master/13-Advanced Python Modules'

# %%
f = open('practice.txt', 'w+')

f.write('This is a test string')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master/13-Advanced Python Modules'

# %%
os.listdir()
# Out:
# ['Opening-and-Reading-Files-Folders.ipynb',
#  '# ADVANCED PYTHON MODULES.ipynb',
#  'Untitled.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '05-Regular Expressions - re.ipynb',
#  'practice.txt',
#  '06-StringIO.ipynb',
#  '02-Datetime.ipynb',
#  '01-Collections Module.ipynb',
#  '.ipynb_checkpoints',
#  '04-Timing your code - timeit.ipynb']

# %%
os.listdir('/Users')
# Out:
# ['.localized', 'veronika', 'Shared']

# %%
import shutil

# %%
shutil.move('practice.txt', '/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master')
# Out:
# '/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master/practice.txt'

# %%
os.listdir('/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master')
# Out:
# ['14-Advanced Python Objects and Data Structures',
#  '07-S.ipynb',
#  '03-05.ipynb',
#  '02-05.ipynb',
#  '17-Parallel Processing',
#  '03-Methods and Functions',
#  '07-Errors and Exception Handling',
#  '.DS_Store',
#  'somefile.txt',
#  '03-01.ipynb',
#  'FAQ.ipynb',
#  '02-03.ipynb',
#  '11-Python Generators',
#  '06-Modules and Packages',
#  '01-Python Comparison Operators',
#  '05-01.ipynb',
#  '02-04.ipynb',
#  '08-F.ipynb',
#  '06-T.ipynb',
#  '03-06.ipynb',
#  '02-06.ipynb',
#  'practice.txt',
#  'Jupyter (iPython) Notebooks Guide.ipynb',
#  '02-02.ipynb',
#  '08-Milestone Project - 2',
#  '04-L.ipynb',
#  '12-Final Capstone Python Project',
#  'README.md',
#  '15-Advanced OOP',
#  '05-D.ipynb',
#  '16-Bonus Material - Introduction to GUIs',
#  '13-Advanced Python Modules',
#  '09-Built-in Functions',
#  '04-Milestone Project - 1',
#  '05-Object Oriented Programming',
#  'myfile.txt',
#  '00-Python Object and Data Structure Basics',
#  '.git',
#  '10-Python Decorators',
# ...

# %%
 import send2trash

# %%
os.listdir()
# Out:
# ['Opening-and-Reading-Files-Folders.ipynb',
#  '# ADVANCED PYTHON MODULES.ipynb',
#  'Untitled.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '05-Regular Expressions - re.ipynb',
#  '06-StringIO.ipynb',
#  '02-Datetime.ipynb',
#  '01-Collections Module.ipynb',
#  '.ipynb_checkpoints',
#  '04-Timing your code - timeit.ipynb']

# %%
shutil.move('/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master/practice.txt', os.getcwd())
# Out:
# '/Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master/13-Advanced Python Modules/practice.txt'

# %%
os.listdir()
# Out:
# ['Opening-and-Reading-Files-Folders.ipynb',
#  '# ADVANCED PYTHON MODULES.ipynb',
#  'Untitled.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '05-Regular Expressions - re.ipynb',
#  'practice.txt',
#  '06-StringIO.ipynb',
#  '02-Datetime.ipynb',
#  '01-Collections Module.ipynb',
#  '.ipynb_checkpoints',
#  '04-Timing your code - timeit.ipynb']

# %%
send2trash.send2trash('practice.txt')

# %%
os.listdir()
# Out:
# ['Opening-and-Reading-Files-Folders.ipynb',
#  '# ADVANCED PYTHON MODULES.ipynb',
#  'Untitled.ipynb',
#  '03-Python Debugger (pdb).ipynb',
#  '05-Regular Expressions - re.ipynb',
#  '06-StringIO.ipynb',
#  '02-Datetime.ipynb',
#  '01-Collections Module.ipynb',
#  '.ipynb_checkpoints',
#  '04-Timing your code - timeit.ipynb']

# %%
file_path = '/Users/veronika/Documents/faks/petaGodina/diplomski/python'

# %%
for folder, sub_folders, files in os.walk(file_path):
    
    print(f'Currently looking at {folder}')
    print('\n')
    print('The subfolders are: ')
    for sub_fold in sub_folders:
        print(f'Subfolder: {sub_fold}')
    
    print('\n')
    print('Files are: ')
    for file in files:
        print(f'File: {file}')
        print('\n')
# Out:
# Currently looking at /Users/veronika/Documents/faks/petaGodina/diplomski/python
#
#
# The subfolders are:
# Subfolder: __pycache__
# Subfolder: Complete-Python-3-Bootcamp-master
#
#
# Files are:
# File: .DS_Store
#
#
# Currently looking at /Users/veronika/Documents/faks/petaGodina/diplomski/python/__pycache__
#
#
# The subfolders are:
#
#
# Files are:
# File: modules.cpython-37.pyc
#
#
# Currently looking at /Users/veronika/Documents/faks/petaGodina/diplomski/python/Complete-Python-3-Bootcamp-master
#
#
# The subfolders are:
# Subfolder: 14-Advanced Python Objects and Data Structures
# Subfolder: 17-Parallel Processing
# Subfolder: 03-Methods and Functions
# Subfolder: 07-Errors and Exception Handling
# Subfolder: 11-Python Generators
# Subfolder: 06-Modules and Packages
# Subfolder: 01-Python Comparison Operators
# Subfolder: 08-Milestone Project - 2
# Subfolder: 12-Final Capstone Python Project
# Subfolder: 15-Advanced OOP
# Subfolder: 16-Bonus Material - Introduction to GUIs
# ...
